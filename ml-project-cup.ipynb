# %%
# !git clone https://github.com/lorenzoleuzzi1/ml-project.git
# Out:
# Cloning into 'ml-project'...
# remote: Enumerating objects: 604, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 604 (delta 116), reused 120 (delta 80), pack-reused 436
# Receiving objects: 100% (604/604), 3.11 MiB | 5.75 MiB/s, done.
# Resolving deltas: 100% (392/392), done.

# %%
# %cd ml-project
# !git checkout giulia
# Out:
# /kaggle/working/ml-project
# Branch 'giulia' set up to track remote branch 'giulia' from 'origin'.
# Switched to a new branch 'giulia'

# %%
# !python cup.py
# Out:
# __pycache__/              monks.py                     plot_score.png
# _grid_search.py           monks_cv_results.json        poly_fitting.py
# cup.py                    network.py                   prova.py
# datasets/                 parameters.csv               scores.csv
# example_mnist_fc.py       plot_error.png               test_network.py
# example_xor.py            plot_k-fold_error.png        test_reprod.py
# exploration.ipynb         plot_k-fold_inner_error.png  test_utils.py
# grid_search.py            plot_k-fold_inner_score.png  toy_datasets.py
# grid_search_fix_value.py  plot_k-fold_outer_error.png  utils.py
# layer.py                  plot_k-fold_outer_score.png  validation.py
# load_saved_net.py         plot_k-fold_score.png
# epoch 1/100   train error=338.164502
# epoch 2/100   train error=76.654786
# epoch 3/100   train error=17.270732
# epoch 4/100   train error=12.363121
# epoch 5/100   train error=11.147173
# epoch 6/100   train error=10.333839
# ...
