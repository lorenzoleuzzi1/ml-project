# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

CUP_TRAIN_PATH = './datasets/ML-CUP22-TR.csv'
CUP_TEST_PATH = './datasets/ML-CUP22-TS.csv'

column_names = ['id', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'y1', 'y2']
data = pd.read_csv(CUP_TRAIN_PATH, sep=",", header=None, comment='#', names=column_names)
data.drop(data.columns[0], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      1492 non-null   float64
#  1   x2      1492 non-null   float64
#  2   x3      1492 non-null   float64
#  3   x4      1492 non-null   float64
#  4   x5      1492 non-null   float64
#  5   x6      1492 non-null   float64
#  6   x7      1492 non-null   float64
#  7   x8      1492 non-null   float64
#  8   x9      1492 non-null   float64
#  9   y1      1492 non-null   float64
#  10  y2      1492 non-null   float64
# dtypes: float64(11)
# memory usage: 128.3 KB

# %%
display(data.describe().round(2))
# Out:
#             x1       x2       x3       x4       x5       x6       x7       x8  \
# count  1492.00  1492.00  1492.00  1492.00  1492.00  1492.00  1492.00  1492.00
# mean      0.08     0.01     0.25    -0.06     0.02     0.15     0.23     0.15
# std       1.02     0.97     0.98     0.84     1.00     1.03     1.00     1.05
# min      -2.29    -2.08    -3.06    -1.91    -2.22    -2.12    -2.97    -2.62
# 25%      -0.83    -0.85    -0.42    -0.78    -0.92    -0.79    -0.48    -0.77
# 50%       0.22     0.05     0.20    -0.04     0.13     0.22     0.03     0.19
# 75%       0.93     0.79     0.90     0.62     0.88     1.02     1.05     1.06
# max       2.24     2.62     2.87     2.09     1.91     2.44     2.62     2.36
#
#             x9       y1       y2
# count  1492.00  1492.00  1492.00
# mean      0.11    11.47   -26.51
# std       1.04     6.49     4.23
# min      -2.42     1.87   -33.89
# 25%      -0.85     5.10   -29.66
# 50%       0.28    10.45   -27.73
# ...

# %%
sns.histplot(data, x="y1", y="y2")
# Out:
# <AxesSubplot:xlabel='y1', ylabel='y2'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
pair = data.iloc[:, 0:11]
sns.pairplot(pair, diag_kind='kde')

# %%
data.hist(figsize=(20,15),bins=20)
plt.show()

# %%
data.boxplot(figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(), cmap=plt.cm.Reds, annot=True)
plt.show()
